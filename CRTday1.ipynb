# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhil7013/CRT_ADVANCE_PYTHON/blob/main/CRTday1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(2,10,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
x=10
for i in range(20,10,-2):
  x=x+2
  print("Hi")
for i in "Hi":
  print(x,end=" ")
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# 20 20

# %%
z=3
for i in "island":
  z=z+1
s = z
for i in range(z):
  s=s+i
print(s)
# Out:
# 45

# %%
l = 30
b = 8

for i in range (b):
  if(i == 0 or i == b-1):
    for j in range(l):
      print('*', end ='')
    print()
  else:
    print('*', end =' ')
    for j in range(l-2):
      print('', end=' ')
    print('*')
# Out:
# ******************************
# *                             *
# *                             *
# *                             *
# *                             *
# *                             *
# *                             *
# ******************************

# %%
x = int(input('Enter the Number:'))
for i in range (1,x+1,1):
  print(f'{i} x {x} = {x*i}')
# Out:
# Enter the Number:12
# 1 x 12 = 12
# 2 x 12 = 24
# 3 x 12 = 36
# 4 x 12 = 48
# 5 x 12 = 60
# 6 x 12 = 72
# 7 x 12 = 84
# 8 x 12 = 96
# 9 x 12 = 108
# 10 x 12 = 120
# 11 x 12 = 132
# 12 x 12 = 144

# %%
a=input("Enter any Sentence: ")
c=0
for i in a:
  if i ==" ":
    c=c+1
print("The total words: ",c+1)
# Out:
# Enter any Sentence: my love
# The total words:  2

# %%
a=input("Enter any Sentence: ")
c=0
for i in range(len(a)):
  if a[i]==" " and a[i+1]!=" ":
    c=c+1
print("Words: ",c+1)
# Out:
# Enter any Sentence: i name Nikhil
# Words:  3
